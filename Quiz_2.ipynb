# %% [markdown]
# <a href="https://colab.research.google.com/github/A01199130/-A2-Tipos-de-variables/blob/main/Quiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Name that characterizes the dataset:**
#
# Average quarterly monetary current expenditure by federal entity according to major expenditure categories

# %% [markdown]
# **2. Organization that generated it**
#
# National Institute of Statistics and Geography (INEGI)

# %% [markdown]
# **3. Download link of the dataset:** https://www.inegi.org.mx/app/tabulados/interactivos/?pxq=Hogares_Hogares_12_60ab9bc6-fec2-4737-a8a5-3d3b435398b6&idrt=54&opc=t

# %% [markdown]
#  **3.1 CSV file of the dataset:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/Average quarterly monetary current expenditure by federal entity according to major expenditure categories(Hoja1).csv", encoding='ISO-8859-1')
df.head(34)
# Out:
#                  Entidad federativa   Total Alimentos, bebidas y tabaco  \
# 0          Estados Unidos Mexicanos  47,674                      17,982
# 1                    Aguascalientes  53,870                      18,319
# 2                   Baja California  55,269                      19,444
# 3               Baja California Sur  55,939                      18,559
# 4                          Campeche  41,574                      16,620
# 5              Coahuila de Zaragoza  50,501                      16,083
# 6                            Colima  52,016                      19,275
# 7                           Chiapas  27,118                      12,605
# 8                         Chihuahua  46,881                      15,461
# 9                  Ciudad de México  66,383                      24,389
# 10                          Durango  42,456                      13,924
# 11                       Guanajuato  45,570                      17,126
# ...

# %% [markdown]
# **4. Description of the dataset:**
# The dataset shows the average quarterly household expenditure by state in Mexico, divided into different categories. The information is expressed in Mexican pesos and corresponds to the year 2024, allowing for comparison of consumption patterns across states.
#
# **Characteristics of the dataset:**
#
# rows: 56
#
# columns: 11
#
# units: Pesos MX
#
# Period: 2024
#
# **Categories:**
#
# -Total
# -Food, beverages and tobacco
# -Clothing and footwear
# -Housing, maintenance, electricity and fuels
# -Articles and services for cleaning, household care and domestic appliances
# -Health care
# -Transportation, communications and related services
# -Education services, educational articles, recreation and culture
# -Personal care and other miscellaneous expenses
# -Expenditure transfers

# %% [markdown]
# **5. Unclear identifier and how to investigate it:**
#
# An identifier that is not very clear is the category “Articles and services for cleaning, household care and domestic appliances”, since it does not specify which exact products it includes.
#
# **To investigate it, It could be:**
#
# -Search for a methodological glossary provided by INEGI.
#
# -Consult the technical sheet that accompanies the dataset.
#
# -Analyze the ENIGH microdata, where the codes and classification of each  expenditure category are detailed.

# %% [markdown]
# **6. What questions could be answered with this data?**
#
# Which states have a higher percentage of expenditure on food, beverages, and tobacco?
#
# How does spending on health, housing, and transportation vary among states?
#
# Are there major differences in the spending patterns across the regions of the country?

# %% [markdown]
# **7. Research question of interest**
#
# Is there a relationship between the level of health expenditure and food expenditure among the states of Mexico?

# %% [markdown]
# **8. Skateholders**
#
# **Food and beverage companies:** these seek information to understand demand and consumption habits in different states.
#
# **Academic and research institutions:** interested in analyzing consumption patterns and their relationship with well-being indicators.
#
# **Government:** uses this type of information to design public policies on food, health, and social development.
